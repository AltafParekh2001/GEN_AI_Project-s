# %% [markdown]
# <a href="https://colab.research.google.com/github/AltafParekh2001/GEN_AI_Project-s/blob/main/Youtube_Vedio_Script_Summarizer_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import inspect
# !pip install --upgrade youtube-transcript-api transformers

from youtube_transcript_api import YouTubeTranscriptApi
from transformers import pipeline
import re

def get_video_id(url):
    """Extract YouTube video ID from URL."""
    pattern = r"(?:v=|/)([0-9A-Za-z_-]{11}).*"
    match = re.search(pattern, url)
    return match.group(1) if match else None


def get_youtube_transcript(url, lang='en'):
    video_id = get_video_id(url)

    try:
        # Create instance first
        ytt_api = YouTubeTranscriptApi()

        # Use .fetch() method
        fetched_transcript = ytt_api.fetch(video_id, languages=[lang, 'en'])

        # Convert to raw data
        transcript = fetched_transcript.to_raw_data()

        # Combine text
        text = " ".join([entry['text'] for entry in transcript])
        return text
    except Exception as e:
        print(f"Error: {e}")
        return None


def summarize_text(text):
    """Summarize long text using a transformer model."""
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
    summary = summarizer(text, max_length=200, min_length=50, do_sample=False)
    return summary[0]['summary_text']

# 🎥 Example usage
url = input("Enter YouTube video URL: ")
transcript = get_youtube_transcript(url)

if transcript:
    print("\n📝 Transcript Preview:\n")
    print(transcript[:1000], "...")

    print("\n🔍 Generating Summary...\n")
    summary = summarize_text(transcript[:4000])
    print("\n📘 Summary:\n", summary)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.1/485.1 kB 11.7 MB/s eta 0:00:00
# ...
# Enter YouTube video URL: https://www.youtube.com/watch?v=h9Z4oGN89MU
#
# 📝 Transcript Preview:
#
# How many calculations do you think your
# graphics card performs every second   while running video games with incredibly
# realistic graphics? Maybe 100 million? Well,   100 million calculations a second is what’s
# required to run Mario 64 from 1996. We need   more power. Maybe 100 billion calculations a
# second? Well, then you would have a computer   that could run Minecraft back in 2011. In order
# to run the most realistic video games such as   Cyberpunk 2077 you need a graphics card that can
# perform around 36 trillion calculations a second.  This is an unimaginably large number, so let’s
# take a second to try to conceptualize it. Imagine   doing a long multiplication problem once every
# second. Now let’s say everyone on the planet does   a similar type of calculation but with different
# ...
